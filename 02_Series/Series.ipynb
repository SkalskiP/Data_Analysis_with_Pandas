# %% [markdown]
# ## Series

# %% [markdown]
# ### 1. Create A Series Object from A Python List

# %%
import pandas as pd

# %%
ice_cream = ["Chocolate", "Vanilla", "Strawberry", "Rum Raisin"]
pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3    Rum Raisin
# dtype: object

# %%
lottery = [4, 8, 15, 16, 23, 42]
pd.Series(lottery)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
registrations = [True, False, False, False, True]
pd.Series(registrations)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ### 2. Create A Series Object from a Dictionary

# %%
webster = {
    "Aardvark" : "An animal",
    "Banana" : "A delicious fruit",
    "Cyan" : "A color"
}

pd.Series(webster)
# Out:
# Aardvark            An animal
# Banana      A delicious fruit
# Cyan                  A color
# dtype: object

# %% [markdown]
# ### 3. Intro to Attributes

# %%
about_me = ["Smart", "Handsom", "Charming", "Brilliant", "Humble"]
s = pd.Series(about_me)
s
# Out:
# 0        Smart
# 1      Handsom
# 2     Charming
# 3    Brilliant
# 4       Humble
# dtype: object

# %%
s.values
# Out:
# array(['Smart', 'Handsom', 'Charming', 'Brilliant', 'Humble'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### 4. Intro to Methods

# %%
prices = [2.99, 4.45, 1.36]
s = pd.Series(prices)
s
# Out:
# 0    2.99
# 1    4.45
# 2    1.36
# dtype: float64

# %%
s.sum()
# Out:
# 8.8

# %%
s.product()
# Out:
# 18.095480000000006

# %%
s.mean()
# Out:
# 2.9333333333333336

# %% [markdown]
# ### 5. Parameters and Arguments

# %%
# Difficulty - Easy, Medium, Hard
# Volume - 1 through 10
# Subtitles - True/False

# %%
fruits = ["Apple", "Orange", "Plum", "Grape", "Blueberry"]
weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

pd.Series(fruits, weekdays)
pd.Series(data = fruits, index = weekdays)
pd.Series(fruits, index = weekdays)
# Out:
# Monday           Apple
# Tuesday         Orange
# Wednesday         Plum
# Thursday         Grape
# Friday       Blueberry
# dtype: object

# %%
fruits = ["Apple", "Orange", "Plum", "Grape", "Blueberry", "Watermelon"]
weekdays = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Monday"]

pd.Series(data = fruits, index = weekdays)
# Out:
# Monday            Apple
# Tuesday          Orange
# Wednesday          Plum
# Thursday          Grape
# Friday        Blueberry
# Monday       Watermelon
# dtype: object

# %% [markdown]
# <b>NOTE:</b> Indexes do not have to be unique.

# %% [markdown]
# ### 6. Import Series with rhe read_csv Method

# %%
pokemon = pd.read_csv('../00_Datasers/pokemon.csv', usecols = ["Pokemon"], squeeze=True)
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
google = pd.read_csv("../00_Datasers/google_stock_price.csv", squeeze=True)
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
# 5        53.90
# 6        53.02
# 7        50.95
# 8        51.13
# 9        50.07
# 10       50.70
# 11       49.95
# 12       50.74
# 13       51.10
# 14       51.10
# 15       52.61
# 16       53.70
# 17       55.69
# 18       55.94
# 19       56.93
# 20       58.69
# 21       59.62
# 22       58.86
# 23       59.13
# 24       60.35
# 25       59.86
# 26       59.07
# 27       63.37
# 28       65.47
# 29       64.74
#          ...
# 2982    675.22
# 2983    668.26
# 2984    680.04
# 2985    684.11
# 2986    692.10
# 2987    699.21
# 2988    694.49
# 2989    697.77
# 2990    695.36
# 2991    705.63
# 2992    715.09
# 2993    720.64
# 2994    716.98
# 2995    720.95
# 2996    719.85
# 2997    733.78
# 2998    736.96
# 2999    741.19
# 3000    738.63
# 3001    742.74
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# ...

# %% [markdown]
# ### 7. The .head() and .tail() Methods

# %%
pokemon = pd.read_csv('../00_Datasers/pokemon.csv', usecols = ["Pokemon"], squeeze=True)
google = pd.read_csv("../00_Datasers/google_stock_price.csv", squeeze=True)

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
google.tail()
# Out:
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, dtype: float64

# %% [markdown]
# ### 8. Python Built-In Functions

# %%
len(pokemon)
len(google)
# Out:
# 3012

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
sorted(pokemon)
sorted(google)
# Out:
# [49.950000000000003,
#  50.07,
#  50.119999999999997,
#  50.700000000000003,
#  50.740000000000002,
#  50.950000000000003,
#  51.100000000000001,
#  51.100000000000001,
#  51.130000000000003,
#  52.380000000000003,
#  52.609999999999999,
#  52.950000000000003,
#  53.020000000000003,
#  53.700000000000003,
#  53.899999999999999,
#  54.100000000000001,
#  54.649999999999999,
#  55.689999999999998,
#  55.939999999999998,
#  56.93,
#  58.689999999999998,
#  58.859999999999999,
#  59.07,
#  59.130000000000003,
#  59.619999999999997,
#  59.859999999999999,
#  60.350000000000001,
#  63.369999999999997,
#  64.739999999999995,
#  65.469999999999999,
#  66.219999999999999,
#  67.459999999999994,
#  67.560000000000002,
#  68.469999999999999,
#  68.629999999999995,
#  68.799999999999997,
#  69.120000000000005,
#  69.359999999999999,
#  70.170000000000002,
#  70.379999999999995,
#  70.930000000000007,
#  71.980000000000004,
#  73.900000000000006,
#  74.510000000000005,
#  74.620000000000005,
# ...

# %%
list(pokemon)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
dict(google)
# Out:
# {0: 50.119999999999997,
#  1: 54.100000000000001,
#  2: 54.649999999999999,
#  3: 52.380000000000003,
#  4: 52.950000000000003,
#  5: 53.899999999999999,
#  6: 53.020000000000003,
#  7: 50.950000000000003,
#  8: 51.130000000000003,
#  9: 50.07,
#  10: 50.700000000000003,
#  11: 49.950000000000003,
#  12: 50.740000000000002,
#  13: 51.100000000000001,
#  14: 51.100000000000001,
#  15: 52.609999999999999,
#  16: 53.700000000000003,
#  17: 55.689999999999998,
#  18: 55.939999999999998,
#  19: 56.93,
#  20: 58.689999999999998,
#  21: 59.619999999999997,
#  22: 58.859999999999999,
#  23: 59.130000000000003,
#  24: 60.350000000000001,
#  25: 59.859999999999999,
#  26: 59.07,
#  27: 63.369999999999997,
#  28: 65.469999999999999,
#  29: 64.739999999999995,
#  30: 66.219999999999999,
#  31: 67.459999999999994,
#  32: 69.120000000000005,
#  33: 68.469999999999999,
#  34: 69.359999999999999,
#  35: 68.799999999999997,
#  36: 67.560000000000002,
#  37: 68.629999999999995,
# ...

# %%
max(pokemon)
# Out:
# 'Zygarde'

# %%
min(pokemon)
# Out:
# 'Abomasnow'

# %% [markdown]
# ### 9. More Series Attributes

# %%
pokemon.is_unique
# Out:
# True

# %%
google.is_unique
# Out:
# False

# %%
pokemon.ndim
google.ndim
# Out:
# 1

# %%
pokemon.shape
# Out:
# (721,)

# %%
# this attribute does count null numbers
pokemon.size
# Out:
# 721

# %%
# name of series
pokemon.name
# Out:
# 'Pokemon'
