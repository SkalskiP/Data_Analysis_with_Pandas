# %% [markdown]
# # Panels

# %%
import pandas
from pandas_datareader import data

# %% [markdown]
# ### 1. The Axes of a Panel Object

# %%
companies = ["MSFT", "GOOG", "AAPL", "YHOO", "AMZN"]
P = data.DataReader(name = companies, data_source="google", start = "2010-01-01", end="2016-12-31")
P
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 251 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2016-10-26 00:00:00 to 2017-10-24 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
P.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
P.major_axis
# Out:
# DatetimeIndex(['2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31',
#                '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                '2016-11-07', '2016-11-08',
#                ...
#                '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-16',
#                '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20',
#                '2017-10-23', '2017-10-24'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
P.axes
# Out:
# [Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object'),
#  DatetimeIndex(['2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31',
#                 '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                 '2016-11-07', '2016-11-08',
#                 ...
#                 '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-16',
#                 '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20',
#                 '2017-10-23', '2017-10-24'],
#                dtype='datetime64[ns]', name='Date', length=251, freq=None),
#  Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')]

# %% [markdown]
# ### 2. Panel Attributes

# %%
P.axes
# Out:
# [Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object'),
#  DatetimeIndex(['2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31',
#                 '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                 '2016-11-07', '2016-11-08',
#                 ...
#                 '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-16',
#                 '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20',
#                 '2017-10-23', '2017-10-24'],
#                dtype='datetime64[ns]', name='Date', length=251, freq=None),
#  Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')]

# %%
P.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
P.major_axis
# Out:
# DatetimeIndex(['2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31',
#                '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                '2016-11-07', '2016-11-08',
#                ...
#                '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-16',
#                '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20',
#                '2017-10-23', '2017-10-24'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
P.minor_axis
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')

# %%
P.ndim
# Out:
# 3

# %%
P.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
P.shape
# Out:
# (5, 251, 5)

# %%
P.size
# Out:
# 6275

# %%
P.values
# Out:
# array([[[  1.14310000e+02,   8.32760000e+02,   8.06340000e+02,
#            6.08100000e+01,   4.22600000e+01],
#         [  1.15390000e+02,   8.31240000e+02,   8.01000000e+02,
#            6.06100000e+01,   4.23100000e+01],
#         [  1.13870000e+02,   7.82000000e+02,   8.08350000e+02,
#            6.00100000e+01,   4.20300000e+01],
#         ...,
#         [  1.56610000e+02,   9.93530000e+02,   9.89440000e+02,
#            7.83200000e+01,   6.76500000e+01],
#         [  1.56890000e+02,   9.86730000e+02,   9.89520000e+02,
#            7.89900000e+01,   6.76300000e+01],
#         [  1.56290000e+02,   9.69000000e+02,   9.70000000e+02,
#            7.89000000e+01,   6.66900000e+01]],
#
#        [[  1.15700000e+02,   8.33440000e+02,   8.06980000e+02,
#            6.12000000e+01,   4.24400000e+01],
#         [  1.15860000e+02,   8.31720000e+02,   8.03490000e+02,
#            6.08300000e+01,   4.24900000e+01],
#         [  1.15210000e+02,   7.89490000e+02,   8.15490000e+02,
# ...

# %%
P.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
P["Open"]
# Out:
#               AAPL     AMZN    GOOG   MSFT   YHOO
# Date
# 2016-10-26  114.31   832.76  806.34  60.81  42.26
# 2016-10-27  115.39   831.24  801.00  60.61  42.31
# 2016-10-28  113.87   782.00  808.35  60.01  42.03
# 2016-10-31  113.65   781.03  795.47  60.16  42.03
# 2016-11-01  113.46   799.00  782.89  59.97  41.13
# 2016-11-02  111.40   783.93  778.20  59.82  41.80
# 2016-11-03  110.98   765.05  767.25  59.53  40.62
# 2016-11-04  108.53   762.79  750.66  58.65  39.96
# 2016-11-07  110.08   771.64  774.50  59.78  41.17
# 2016-11-08  110.31   784.97  783.40  60.55  40.97
# 2016-11-09  109.88   764.00  779.94  60.00  40.44
# 2016-11-10  111.09   778.81  791.17  60.48  41.55
# 2016-11-11  107.12   735.73  756.54  58.23  39.84
# 2016-11-14  107.71   745.51  755.60  59.02  40.36
# 2016-11-15  106.57   730.00  746.97  58.33  39.61
# 2016-11-16  106.70   739.88  755.20  58.94  40.10
# 2016-11-17  109.81   749.32  766.92  60.41  41.34
# 2016-11-18  109.72   761.00  771.37  60.78  41.48
# ...

# %%
P["Volume"].head()
# Out:
#                   AAPL        AMZN       GOOG        MSFT        YHOO
# Date
# 2016-10-26  66134219.0   3998102.0  1647733.0  29911608.0   6123026.0
# 2016-10-27  34562045.0   7406385.0  2749221.0  28479856.0   7240848.0
# 2016-10-28  37861662.0  10841073.0  4269902.0  33574684.0   6197469.0
# 2016-10-31  26419398.0   5413326.0  2427284.0  26434697.0   3749658.0
# 2016-11-01  43825812.0   5305428.0  2406356.0  24532986.0  11751521.0

# %%
P.Volume.head()
# Out:
#                   AAPL        AMZN       GOOG        MSFT        YHOO
# Date
# 2016-10-26  66134219.0   3998102.0  1647733.0  29911608.0   6123026.0
# 2016-10-27  34562045.0   7406385.0  2749221.0  28479856.0   7240848.0
# 2016-10-28  37861662.0  10841073.0  4269902.0  33574684.0   6197469.0
# 2016-10-31  26419398.0   5413326.0  2427284.0  26434697.0   3749658.0
# 2016-11-01  43825812.0   5305428.0  2406356.0  24532986.0  11751521.0

# %% [markdown]
# ### 3. Extracting with the .loc, .iloc, and .ix Methods

# %%
P.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
P.loc["Low", "2016-11-08", "GOOG"]
# Out:
# 780.19000000000005

# %%
P.iloc[3, 200, 3]
# Out:
# 73.590000000000003

# %% [markdown]
# ### 4. Convert Panel to a MultiIndex DataFrame (and Vice Versa)

# %%
df = P.to_frame()
df.head()
# Out:
#                     Open    High     Low   Close      Volume
# Date       minor
# 2016-10-26 AAPL   114.31  115.70  113.31  115.59  66134219.0
#            AMZN   832.76  833.44  820.00  822.59   3998102.0
#            GOOG   806.34  806.98  796.32  799.07   1647733.0
#            MSFT    60.81   61.20   60.47   60.63  29911608.0
#            YHOO    42.26   42.44   41.95   42.08   6123026.0

# %%
p2 = df.to_panel()
p2
# Out:
# C:\Users\AFGHAN92\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   """Entry point for launching an IPython kernel.
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 251 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2016-10-26 00:00:00 to 2017-10-24 00:00:00
# Minor_axis axis: AAPL to YHOO

# %% [markdown]
# ### 5. The .major_xs() Method

# %%
P.items
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
P["Volume"]
# Out:
#                   AAPL        AMZN       GOOG        MSFT        YHOO
# Date
# 2016-10-26  66134219.0   3998102.0  1647733.0  29911608.0   6123026.0
# 2016-10-27  34562045.0   7406385.0  2749221.0  28479856.0   7240848.0
# 2016-10-28  37861662.0  10841073.0  4269902.0  33574684.0   6197469.0
# 2016-10-31  26419398.0   5413326.0  2427284.0  26434697.0   3749658.0
# 2016-11-01  43825812.0   5305428.0  2406356.0  24532986.0  11751521.0
# 2016-11-02  28331709.0   5026504.0  1918414.0  22147005.0  13019956.0
# 2016-11-03  26932602.0   3872496.0  1943175.0  21600427.0   8112820.0
# 2016-11-04  30836997.0   5122103.0  2134812.0  28697016.0   4579437.0
# 2016-11-07  32560000.0   5984354.0  1585070.0  31664798.0   5430744.0
# 2016-11-08  24254179.0   3412629.0  1366873.0  22935355.0   4229743.0
# 2016-11-09  59176361.0   8562892.0  2607121.0  49632479.0  24000065.0
# 2016-11-10  57134541.0  12746994.0  4745183.0  57822394.0  16443786.0
# ...

# %%
P.major_axis
# Out:
# DatetimeIndex(['2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31',
#                '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                '2016-11-07', '2016-11-08',
#                ...
#                '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-16',
#                '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20',
#                '2017-10-23', '2017-10-24'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
P.major_xs("2017-09-06")
# Out:
#         Open    High     Low   Close      Volume
# AAPL  162.71  162.99  160.52  161.91  21651726.0
# AMZN  968.32  971.84  960.60  967.80   2129861.0
# GOOG  930.15  930.92  919.27  927.81   1527650.0
# MSFT   73.74   74.04   73.35   73.40  16535785.0
# YHOO   63.71   64.28   62.90   63.32   4875988.0

# %% [markdown]
# ### 6. The .minor_xs() Method

# %%
P.minor_axis
# Out:
# Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')

# %%
P.minor_xs("MSFT")
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2016-10-26  60.81  61.20  60.47  60.63  29911608.0
# 2016-10-27  60.61  60.83  60.09  60.10  28479856.0
# 2016-10-28  60.01  60.52  59.58  59.87  33574684.0
# 2016-10-31  60.16  60.42  59.92  59.92  26434697.0
# 2016-11-01  59.97  60.02  59.25  59.80  24532986.0
# 2016-11-02  59.82  59.93  59.30  59.43  22147005.0
# 2016-11-03  59.53  59.64  59.11  59.21  21600427.0
# 2016-11-04  58.65  59.28  58.52  58.71  28697016.0
# 2016-11-07  59.78  60.52  59.78  60.42  31664798.0
# 2016-11-08  60.55  60.78  60.15  60.47  22935355.0
# 2016-11-09  60.00  60.59  59.20  60.17  49632479.0
# 2016-11-10  60.48  60.49  57.63  58.70  57822394.0
# 2016-11-11  58.23  59.12  58.01  59.02  38767843.0
# 2016-11-14  59.02  59.08  57.28  58.12  41328422.0
# 2016-11-15  58.33  59.49  58.32  58.87  35904126.0
# 2016-11-16  58.94  59.66  58.81  59.65  27332475.0
# 2016-11-17  60.41  60.95  59.96  60.64  31463728.0
# ...

# %%
P.minor_xs("GOOG").head(3)
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2016-10-26  806.34  806.98  796.32  799.07  1647733.0
# 2016-10-27  801.00  803.49  791.50  795.35  2749221.0
# 2016-10-28  808.35  815.49  793.59  795.37  4269902.0

# %% [markdown]
#  ### 7. Transpose a Panel with the .transpose() Method

# %%
P.axes
# Out:
# [Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object'),
#  DatetimeIndex(['2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31',
#                 '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                 '2016-11-07', '2016-11-08',
#                 ...
#                 '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-16',
#                 '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20',
#                 '2017-10-23', '2017-10-24'],
#                dtype='datetime64[ns]', name='Date', length=251, freq=None),
#  Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object')]

# %%
P2 = P.transpose(2, 1, 0)

# %%
P
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 251 (major_axis) x 5 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2016-10-26 00:00:00 to 2017-10-24 00:00:00
# Minor_axis axis: AAPL to YHOO

# %%
P2
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 251 (major_axis) x 5 (minor_axis)
# Items axis: AAPL to YHOO
# Major_axis axis: 2016-10-26 00:00:00 to 2017-10-24 00:00:00
# Minor_axis axis: Open to Volume

# %%
P2["AAPL"]
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2016-10-26  114.31  115.70  113.31  115.59  66134219.0
# 2016-10-27  115.39  115.86  114.10  114.48  34562045.0
# 2016-10-28  113.87  115.21  113.45  113.72  37861662.0
# 2016-10-31  113.65  114.23  113.20  113.54  26419398.0
# 2016-11-01  113.46  113.77  110.53  111.49  43825812.0
# 2016-11-02  111.40  112.35  111.23  111.59  28331709.0
# 2016-11-03  110.98  111.46  109.55  109.83  26932602.0
# 2016-11-04  108.53  110.25  108.11  108.84  30836997.0
# 2016-11-07  110.08  110.51  109.46  110.41  32560000.0
# 2016-11-08  110.31  111.72  109.70  111.06  24254179.0
# 2016-11-09  109.88  111.32  108.05  110.88  59176361.0
# 2016-11-10  111.09  111.09  105.83  107.79  57134541.0
# 2016-11-11  107.12  108.87  106.55  108.43  34143898.0
# 2016-11-14  107.71  107.81  104.08  105.71  51175504.0
# 2016-11-15  106.57  107.68  106.16  107.11  32264510.0
# 2016-11-16  106.70  110.23  106.60  109.99  58840522.0
# ...

# %% [markdown]
# ### 8. The .swapaxes() Method

# %%
P3 = P.swapaxes("items", "minor")
# Out:
# C:\Users\AFGHAN92\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   """Entry point for launching an IPython kernel.

# %%
P3.axes
# Out:
# [Index(['AAPL', 'AMZN', 'GOOG', 'MSFT', 'YHOO'], dtype='object'),
#  DatetimeIndex(['2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31',
#                 '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#                 '2016-11-07', '2016-11-08',
#                 ...
#                 '2017-10-11', '2017-10-12', '2017-10-13', '2017-10-16',
#                 '2017-10-17', '2017-10-18', '2017-10-19', '2017-10-20',
#                 '2017-10-23', '2017-10-24'],
#                dtype='datetime64[ns]', name='Date', length=251, freq=None),
#  Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')]

# %%
P3["MSFT"]
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2016-10-26  60.81  61.20  60.47  60.63  29911608.0
# 2016-10-27  60.61  60.83  60.09  60.10  28479856.0
# 2016-10-28  60.01  60.52  59.58  59.87  33574684.0
# 2016-10-31  60.16  60.42  59.92  59.92  26434697.0
# 2016-11-01  59.97  60.02  59.25  59.80  24532986.0
# 2016-11-02  59.82  59.93  59.30  59.43  22147005.0
# 2016-11-03  59.53  59.64  59.11  59.21  21600427.0
# 2016-11-04  58.65  59.28  58.52  58.71  28697016.0
# 2016-11-07  59.78  60.52  59.78  60.42  31664798.0
# 2016-11-08  60.55  60.78  60.15  60.47  22935355.0
# 2016-11-09  60.00  60.59  59.20  60.17  49632479.0
# 2016-11-10  60.48  60.49  57.63  58.70  57822394.0
# 2016-11-11  58.23  59.12  58.01  59.02  38767843.0
# 2016-11-14  59.02  59.08  57.28  58.12  41328422.0
# 2016-11-15  58.33  59.49  58.32  58.87  35904126.0
# 2016-11-16  58.94  59.66  58.81  59.65  27332475.0
# 2016-11-17  60.41  60.95  59.96  60.64  31463728.0
# ...
